# %%
import pandas as pd
df = pd.read_csv('MSFT.csv')

# %%
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1986-03-13    0.088542    0.101563    0.088542    0.097222    0.060163
# 1     1986-03-14    0.097222    0.102431    0.097222    0.100694    0.062311
# 2     1986-03-17    0.100694    0.103299    0.100694    0.102431    0.063386
# 3     1986-03-18    0.102431    0.103299    0.098958    0.099826    0.061774
# 4     1986-03-19    0.099826    0.100694    0.097222    0.098090    0.060700
# ...          ...         ...         ...         ...         ...         ...
# 9604  2024-04-23  404.239990  408.200012  403.059998  407.570007  407.570007
# 9605  2024-04-24  409.559998  412.470001  406.779999  409.059998  409.059998
# 9606  2024-04-25  394.029999  399.890015  388.029999  399.040009  399.040009
# 9607  2024-04-26  412.170013  413.000000  405.760010  406.320007  406.320007
# 9608  2024-04-29  405.420013  406.320007  399.190002  402.250000  402.250000
#
#           Volume
# 0     1031788800
# 1      308160000
# 2      133171200
# 3       67766400
# 4       47894400
# ...          ...
# 9604    15734500
# 9605    15065300
# 9606    40586500
# 9607    29553600
# 9608    19256715
#
# [9609 rows x 7 columns]

# %%
df = df[['Date','Close']]
df
# Out:
#             Date       Close
# 0     1986-03-13    0.097222
# 1     1986-03-14    0.100694
# 2     1986-03-17    0.102431
# 3     1986-03-18    0.099826
# 4     1986-03-19    0.098090
# ...          ...         ...
# 9604  2024-04-23  407.570007
# 9605  2024-04-24  409.059998
# 9606  2024-04-25  399.040009
# 9607  2024-04-26  406.320007
# 9608  2024-04-29  402.250000
#
# [9609 rows x 2 columns]

# %%
import datetime
def str_to_datetime(s):
    split = s.split('-')
    year,month,day = int(split[0]),int(split[1]),int(split[2])
    return datetime.datetime(year = year,month=month,day=day)

datetime_obj = str_to_datetime('1999-04-29')
datetime_obj
# Out:
# datetime.datetime(1999, 4, 29, 0, 0)

# %%
df['Date'] = df['Date'].apply(str_to_datetime)
df['Date']
# Out:
# /var/folders/nr/5ljk6lzn0zg1s68vxnxj8xfh0000gn/T/ipykernel_2336/2565755782.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = df['Date'].apply(str_to_datetime)
# 0      1986-03-13
# 1      1986-03-14
# 2      1986-03-17
# 3      1986-03-18
# 4      1986-03-19
#           ...
# 9604   2024-04-23
# 9605   2024-04-24
# 9606   2024-04-25
# 9607   2024-04-26
# 9608   2024-04-29
# Name: Date, Length: 9609, dtype: datetime64[ns]

# %%
df.index = df.pop('Date')

# %%
df
# Out:
#                  Close
# Date
# 1986-03-13    0.097222
# 1986-03-14    0.100694
# 1986-03-17    0.102431
# 1986-03-18    0.099826
# 1986-03-19    0.098090
# ...                ...
# 2024-04-23  407.570007
# 2024-04-24  409.059998
# 2024-04-25  399.040009
# 2024-04-26  406.320007
# 2024-04-29  402.250000
#
# [9609 rows x 1 columns]

# %%
import matplotlib.pyplot as plt
plt.plot(df.index,df['Close'])

# %%
import numpy as np

def df_to_windowed_df(dataframe, first_date_str, last_date_str, n=3):
  first_date = str_to_datetime(first_date_str)
  last_date  = str_to_datetime(last_date_str)

  target_date = first_date
  
  dates = []
  X, Y = [], []

  last_time = False
  while True:
    df_subset = dataframe.loc[:target_date].tail(n+1)
    
    if len(df_subset) != n+1:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = df_subset['Close'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=7)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))
    
    if last_time:
      break
    
    target_date = next_date

    if target_date == last_date:
      last_time = True
    
  ret_df = pd.DataFrame({})
  ret_df['Target Date'] = dates
  
  X = np.array(X)
  for i in range(0, n):
    X[:, i]
    ret_df[f'Target-{n-i}'] = X[:, i]
  
  ret_df['Target'] = Y

  return ret_df

# Start day second time around: '2021-03-25'
windowed_df = df_to_windowed_df(df, 
                                '2021-03-25', 
                                '2022-03-23', 
                                n=3)
windowed_df
# Out:
#     Target Date    Target-3    Target-2    Target-1      Target
# 0    2021-03-25  235.990005  237.580002  235.460007  232.339996
# 1    2021-03-26  237.580002  235.460007  232.339996  236.479996
# 2    2021-03-29  235.460007  232.339996  236.479996  235.240005
# 3    2021-03-30  232.339996  236.479996  235.240005  231.850006
# 4    2021-03-31  236.479996  235.240005  231.850006  235.770004
# ..          ...         ...         ...         ...         ...
# 247  2022-03-17  276.440002  287.149994  294.390015  295.220001
# 248  2022-03-18  287.149994  294.390015  295.220001  300.429993
# 249  2022-03-21  294.390015  295.220001  300.429993  299.160004
# 250  2022-03-22  295.220001  300.429993  299.160004  304.059998
# 251  2022-03-23  300.429993  299.160004  304.059998  299.489990
#
# [252 rows x 5 columns]

# %%
def windowed_df_to_Date_X_y(windowed_dataframe):
    df_as_np = windowed_dataframe.to_numpy()
    dates = df_as_np[:,0]

    middle_matrix = df_as_np[:,1:-1]
    X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

    Y = df_as_np[:,-1]

    return dates, X.astype(np.float32),Y.astype(np.float32)

dates,X,y = windowed_df_to_Date_X_y(windowed_df)
dates.shape,X.shape,y.shape
# Out:
# ((252,), (252, 3, 1), (252,))

# %%
q_80 = int(len(dates) * 0.8)
q_90 = int(len(dates)* 0.9)

dates_train,X_train,y_train = dates[:q_80], X[:q_80],y[:q_80]
dates_val,X_val,y_val = dates[q_80:q_90],X[q_80:q_90],y[q_80:q_90]

dates_test,X_test,y_test = dates[q_90:],X[q_90:],y[q_90:]

plt.plot(dates_train,y_train)
plt.plot(dates_val,y_val)
plt.plot(dates_test,y_test)

plt.legend(['Train','Validation','Test'])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

model = Sequential([layers.Input((3, 1)),
                    layers.LSTM(64),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(1)])

model.compile(loss='mse', 
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100)
# Out:
# Epoch 1/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 82884.5234 - mean_absolute_error: 286.1190 - val_loss: 92239.3516 - val_mean_absolute_error: 303.6221
# Epoch 2/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 84755.0938 - mean_absolute_error: 289.3681 - val_loss: 92048.9297 - val_mean_absolute_error: 303.3083
# Epoch 3/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 83319.5078 - mean_absolute_error: 286.9043 - val_loss: 91838.4531 - val_mean_absolute_error: 302.9612
# Epoch 4/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 84318.5859 - mean_absolute_error: 288.5540 - val_loss: 91567.9531 - val_mean_absolute_error: 302.5144
# Epoch 5/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 83854.1172 - mean_absolute_error: 287.9179 - val_loss: 91169.7188 - val_mean_absolute_error: 301.8555
# Epoch 6/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 83221.8438 - mean_absolute_error: 286.7182 - val_loss: 90520.9375 - val_mean_absolute_error: 300.7788
# Epoch 7/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 81447.4688 - mean_absolute_error: 283.5656 - val_loss: 89460.1875 - val_mean_absolute_error: 299.0103
# Epoch 8/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 80477.8281 - mean_absolute_error: 281.8990 - val_loss: 87899.8984 - val_mean_absolute_error: 296.3897
# Epoch 9/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 80764.0938 - mean_absolute_error: 282.3599 - val_loss: 85892.1172 - val_mean_absolute_error: 292.9832
# Epoch 10/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 79450.5469 - mean_absolute_error: 280.1079 - val_loss: 83593.9375 - val_mean_absolute_error: 289.0344
# Epoch 11/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 76571.8750 - mean_absolute_error: 274.8048 - val_loss: 80464.5000 - val_mean_absolute_error: 283.5692
# Epoch 12/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 72026.1094 - mean_absolute_error: 266.3905 - val_loss: 77030.0703 - val_mean_absolute_error: 277.4474
# Epoch 13/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 69768.0312 - mean_absolute_error: 262.2987 - val_loss: 73199.2891 - val_mean_absolute_error: 270.4557
# Epoch 14/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 63779.5391 - mean_absolute_error: 250.6057 - val_loss: 68732.8125 - val_mean_absolute_error: 262.0684
# Epoch 15/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 61164.7734 - mean_absolute_error: 245.3461 - val_loss: 64022.2500 - val_mean_absolute_error: 252.9215
# Epoch 16/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 55972.2695 - mean_absolute_error: 234.4308 - val_loss: 58890.2031 - val_mean_absolute_error: 242.5638
# Epoch 17/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 50845.8594 - mean_absolute_error: 223.3548 - val_loss: 53101.6367 - val_mean_absolute_error: 230.3230
# Epoch 18/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 46228.8594 - mean_absolute_error: 212.5496 - val_loss: 47311.8750 - val_mean_absolute_error: 217.3911
# Epoch 19/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 39786.4219 - mean_absolute_error: 196.9852 - val_loss: 41197.0977 - val_mean_absolute_error: 202.8401
# Epoch 20/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 35118.8672 - mean_absolute_error: 184.6651 - val_loss: 35177.2891 - val_mean_absolute_error: 187.4147
# Epoch 21/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 29476.1152 - mean_absolute_error: 168.6189 - val_loss: 28543.8809 - val_mean_absolute_error: 168.7911
# Epoch 22/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 23562.3848 - mean_absolute_error: 150.1001 - val_loss: 22286.5781 - val_mean_absolute_error: 149.1094
# Epoch 23/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 17060.7637 - mean_absolute_error: 126.9520 - val_loss: 17121.7246 - val_mean_absolute_error: 130.6475
# Epoch 24/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 13371.5859 - mean_absolute_error: 111.2645 - val_loss: 12565.7998 - val_mean_absolute_error: 111.8604
# Epoch 25/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9883.5312 - mean_absolute_error: 93.7546 - val_loss: 8544.8818 - val_mean_absolute_error: 92.1517
# Epoch 26/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6060.1343 - mean_absolute_error: 71.8084 - val_loss: 5652.2246 - val_mean_absolute_error: 74.8282
# Epoch 27/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4149.6963 - mean_absolute_error: 55.4634 - val_loss: 3514.5337 - val_mean_absolute_error: 58.8351
# Epoch 28/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2666.7334 - mean_absolute_error: 42.0541 - val_loss: 2090.4138 - val_mean_absolute_error: 45.1381
# Epoch 29/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1650.3528 - mean_absolute_error: 32.6082 - val_loss: 1222.7804 - val_mean_absolute_error: 34.2026
# Epoch 30/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1380.3353 - mean_absolute_error: 31.4520 - val_loss: 707.0962 - val_mean_absolute_error: 25.5760
# Epoch 31/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1214.7345 - mean_absolute_error: 29.8047 - val_loss: 441.5162 - val_mean_absolute_error: 19.7117
# Epoch 32/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1081.1211 - mean_absolute_error: 28.3887 - val_loss: 307.5306 - val_mean_absolute_error: 15.9552
# Epoch 33/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1019.8054 - mean_absolute_error: 27.0533 - val_loss: 249.3871 - val_mean_absolute_error: 14.1517
# Epoch 34/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 982.3725 - mean_absolute_error: 26.6835 - val_loss: 222.5214 - val_mean_absolute_error: 13.2375
# Epoch 35/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1082.9629 - mean_absolute_error: 28.1804 - val_loss: 220.3378 - val_mean_absolute_error: 13.1601
# Epoch 36/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1052.5386 - mean_absolute_error: 27.3028 - val_loss: 224.0478 - val_mean_absolute_error: 13.2914
# Epoch 37/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 957.8917 - mean_absolute_error: 26.1503 - val_loss: 237.6353 - val_mean_absolute_error: 13.7624
# Epoch 38/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 927.6379 - mean_absolute_error: 25.4855 - val_loss: 419.9279 - val_mean_absolute_error: 19.2015
# Epoch 39/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 947.1460 - mean_absolute_error: 25.8470 - val_loss: 275.7200 - val_mean_absolute_error: 15.0157
# Epoch 40/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 949.9650 - mean_absolute_error: 26.0776 - val_loss: 352.8514 - val_mean_absolute_error: 17.3764
# Epoch 41/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 994.9639 - mean_absolute_error: 26.8953 - val_loss: 313.8070 - val_mean_absolute_error: 16.2147
# Epoch 42/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 998.2669 - mean_absolute_error: 26.9690 - val_loss: 282.2211 - val_mean_absolute_error: 15.2284
# Epoch 43/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 939.9017 - mean_absolute_error: 26.0572 - val_loss: 275.9430 - val_mean_absolute_error: 15.0418
# Epoch 44/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 948.0295 - mean_absolute_error: 26.0941 - val_loss: 311.6684 - val_mean_absolute_error: 16.1617
# Epoch 45/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 886.4343 - mean_absolute_error: 24.8485 - val_loss: 253.6113 - val_mean_absolute_error: 14.3437
# Epoch 46/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 968.3542 - mean_absolute_error: 26.4482 - val_loss: 244.4829 - val_mean_absolute_error: 14.0485
# Epoch 47/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 963.2471 - mean_absolute_error: 26.7183 - val_loss: 282.8207 - val_mean_absolute_error: 15.2627
# Epoch 48/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 992.3622 - mean_absolute_error: 26.8442 - val_loss: 229.4661 - val_mean_absolute_error: 13.5439
# Epoch 49/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 932.5038 - mean_absolute_error: 25.6415 - val_loss: 236.5513 - val_mean_absolute_error: 13.7920
# Epoch 50/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 903.9650 - mean_absolute_error: 25.4565 - val_loss: 278.4572 - val_mean_absolute_error: 15.1436
# Epoch 51/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 883.5943 - mean_absolute_error: 25.2570 - val_loss: 242.2176 - val_mean_absolute_error: 13.9887
# Epoch 52/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 900.1294 - mean_absolute_error: 25.1573 - val_loss: 251.3199 - val_mean_absolute_error: 14.3014
# Epoch 53/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 918.7009 - mean_absolute_error: 25.8884 - val_loss: 270.0042 - val_mean_absolute_error: 14.9005
# Epoch 54/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 925.1649 - mean_absolute_error: 25.8265 - val_loss: 235.4968 - val_mean_absolute_error: 13.7944
# Epoch 55/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 913.3764 - mean_absolute_error: 25.5117 - val_loss: 284.6058 - val_mean_absolute_error: 15.3933
# Epoch 56/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 856.2433 - mean_absolute_error: 24.7378 - val_loss: 250.0300 - val_mean_absolute_error: 14.3034
# Epoch 57/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 762.7529 - mean_absolute_error: 23.1092 - val_loss: 322.2039 - val_mean_absolute_error: 16.6432
# Epoch 58/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 834.2890 - mean_absolute_error: 24.2320 - val_loss: 364.6773 - val_mean_absolute_error: 17.8815
# Epoch 59/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 774.0062 - mean_absolute_error: 23.4328 - val_loss: 250.0036 - val_mean_absolute_error: 14.3499
# Epoch 60/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 697.4862 - mean_absolute_error: 22.3377 - val_loss: 221.9309 - val_mean_absolute_error: 13.4280
# Epoch 61/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 726.9495 - mean_absolute_error: 22.9714 - val_loss: 275.5646 - val_mean_absolute_error: 15.2857
# Epoch 62/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 700.0801 - mean_absolute_error: 22.3127 - val_loss: 365.0251 - val_mean_absolute_error: 18.0197
# Epoch 63/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 674.7571 - mean_absolute_error: 21.6365 - val_loss: 142.5756 - val_mean_absolute_error: 10.3850
# Epoch 64/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 579.7838 - mean_absolute_error: 20.3486 - val_loss: 151.3136 - val_mean_absolute_error: 10.8152
# Epoch 65/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 504.5904 - mean_absolute_error: 18.6742 - val_loss: 95.4728 - val_mean_absolute_error: 8.0754
# Epoch 66/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 494.7542 - mean_absolute_error: 18.5744 - val_loss: 130.8328 - val_mean_absolute_error: 9.9419
# Epoch 67/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 429.4178 - mean_absolute_error: 17.2536 - val_loss: 172.6113 - val_mean_absolute_error: 11.7848
# Epoch 68/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 408.4802 - mean_absolute_error: 16.7656 - val_loss: 86.7882 - val_mean_absolute_error: 7.7271
# Epoch 69/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 299.4682 - mean_absolute_error: 14.0170 - val_loss: 54.8965 - val_mean_absolute_error: 5.9080
# Epoch 70/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 323.8428 - mean_absolute_error: 14.9751 - val_loss: 103.7704 - val_mean_absolute_error: 8.7203
# Epoch 71/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 239.7741 - mean_absolute_error: 12.3163 - val_loss: 66.0265 - val_mean_absolute_error: 6.6442
# Epoch 72/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 172.2066 - mean_absolute_error: 10.2753 - val_loss: 34.0814 - val_mean_absolute_error: 5.0304
# Epoch 73/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 220.8015 - mean_absolute_error: 12.3035 - val_loss: 40.8453 - val_mean_absolute_error: 5.4267
# Epoch 74/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 186.0009 - mean_absolute_error: 11.3784 - val_loss: 56.2979 - val_mean_absolute_error: 6.1476
# Epoch 75/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 167.2219 - mean_absolute_error: 10.9909 - val_loss: 47.3560 - val_mean_absolute_error: 5.6883
# Epoch 76/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 144.6534 - mean_absolute_error: 10.2204 - val_loss: 35.0611 - val_mean_absolute_error: 4.8833
# Epoch 77/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 110.9297 - mean_absolute_error: 8.7918 - val_loss: 31.3266 - val_mean_absolute_error: 4.9532
# Epoch 78/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 84.4269 - mean_absolute_error: 7.2979 - val_loss: 30.0509 - val_mean_absolute_error: 4.8668
# Epoch 79/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 75.3499 - mean_absolute_error: 6.7705 - val_loss: 30.4798 - val_mean_absolute_error: 4.8757
# Epoch 80/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 61.5695 - mean_absolute_error: 6.1042 - val_loss: 30.0675 - val_mean_absolute_error: 4.8455
# Epoch 81/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 56.7671 - mean_absolute_error: 5.7185 - val_loss: 32.7613 - val_mean_absolute_error: 4.9815
# Epoch 82/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 58.8575 - mean_absolute_error: 5.8062 - val_loss: 30.3674 - val_mean_absolute_error: 4.8386
# Epoch 83/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 54.0738 - mean_absolute_error: 5.9541 - val_loss: 38.8624 - val_mean_absolute_error: 5.0204
# Epoch 84/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 58.9376 - mean_absolute_error: 6.4513 - val_loss: 46.3745 - val_mean_absolute_error: 5.3094
# Epoch 85/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 54.7265 - mean_absolute_error: 6.1412 - val_loss: 59.9953 - val_mean_absolute_error: 6.1026
# Epoch 86/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 47.5189 - mean_absolute_error: 5.7151 - val_loss: 49.7785 - val_mean_absolute_error: 5.5255
# Epoch 87/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 33.2712 - mean_absolute_error: 4.5009 - val_loss: 43.3484 - val_mean_absolute_error: 5.1934
# Epoch 88/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 33.2469 - mean_absolute_error: 4.3633 - val_loss: 43.7016 - val_mean_absolute_error: 5.2248
# Epoch 89/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 37.9440 - mean_absolute_error: 4.7835 - val_loss: 34.3423 - val_mean_absolute_error: 5.0259
# Epoch 90/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 48.5640 - mean_absolute_error: 5.6975 - val_loss: 42.6472 - val_mean_absolute_error: 5.6335
# Epoch 91/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 47.4530 - mean_absolute_error: 5.6365 - val_loss: 31.5107 - val_mean_absolute_error: 4.7808
# Epoch 92/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 30.4256 - mean_absolute_error: 4.2187 - val_loss: 33.0707 - val_mean_absolute_error: 4.8385
# Epoch 93/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 31.6304 - mean_absolute_error: 4.3309 - val_loss: 31.7973 - val_mean_absolute_error: 4.7988
# Epoch 94/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 31.1595 - mean_absolute_error: 4.1913 - val_loss: 32.0686 - val_mean_absolute_error: 4.8008
# Epoch 95/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 27.0387 - mean_absolute_error: 4.0083 - val_loss: 33.2933 - val_mean_absolute_error: 4.8306
# Epoch 96/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 25.5838 - mean_absolute_error: 3.9941 - val_loss: 35.0626 - val_mean_absolute_error: 4.8514
# Epoch 97/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 27.0283 - mean_absolute_error: 3.9221 - val_loss: 38.9458 - val_mean_absolute_error: 4.9797
# Epoch 98/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 23.1787 - mean_absolute_error: 3.7526 - val_loss: 39.9472 - val_mean_absolute_error: 5.0259
# Epoch 99/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 23.2260 - mean_absolute_error: 3.8576 - val_loss: 40.0723 - val_mean_absolute_error: 5.0422
# Epoch 100/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 21.6879 - mean_absolute_error: 3.7742 - val_loss: 34.2174 - val_mean_absolute_error: 4.8281

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations'])

# %%
from copy import deepcopy


recursive_predictions = []
recursive_dates = np.concatenate([dates_val, dates_test])

for target_date in recursive_dates:
    last_window = deepcopy(X_train[-1])
    next_prediction = model.predict(np.array([last_window])).flatten()
    recursive_predictions.append(next_prediction)
    new_window = np.concatenate((last_window[1:], [next_prediction]))  # Append next_prediction to the window
    last_window = new_window
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.plot(recursive_dates, recursive_predictions)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations',
            'Recursive Predictions'])
